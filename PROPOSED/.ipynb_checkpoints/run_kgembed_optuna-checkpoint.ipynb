# %%
from dataloader import AmazonDataset
import models
from models import DistMulti, TransE
from training import TrainIterater
from evaluate import Evaluater
device='cpu'

import optuna
import numpy as np

import torch
from importlib import reload

# %%
# ハイパラ
# 
# embed_dim
# batch_size
# weight_decay, lr, warmup, lr_decay_every, lr_decay_rate
# kg embed model
model_name = 'TransE'
dataset = AmazonDataset('./data', model_name='TransE')
def objective(trial):

    relation_size = len(set(list(dataset.triplet_df['relation'].values)))
    entity_size = len(dataset.entity_list)
    embedding_dim = trial.suggest_discrete_uniform('embedding_dim', 16, 128, 16)
    model = TransE(int(embedding_dim), relation_size, entity_size)
    
    batch_size = trial.suggest_int('batch_size', 128, 512, 128)
    iterater = TrainIterater(batch_size=int(batch_size), model_name=model_name)
    
    lr= trial.suggest_loguniform('lr', 1e-4, 1e-2)
    weight_decay = trial.suggest_loguniform('weight_decay', 1e-6, 1e-2)
    #warmup = trial.suggest_int('warmup', 100, 500)
    warmup = trial.suggest_int('warmup', 1, 5)
    lr_decay_every = trial.suggest_int('lr_decay_every', 1, 10)
    lr_decay_rate = trial.suggest_uniform('lr_decay_rate', 0.5, 1)
    
    score =iterater.iterate_epoch(model, lr=lr, epoch=50, weight_decay=weight_decay, warmup=warmup,
                           lr_decay_rate=lr_decay_rate, lr_decay_every=lr_decay_every, eval_every=10)
    
    return score

# %%
study = optuna.create_study()
study.optimize(objective, n_trials=3)
# Out:
# epoch: 9  precision: 0.2122841539782434
# epoch: 19  precision: 0.2646056281446551
# epoch: 29  precision: 0.27389126488390364
# epoch: 39  precision: 0.2771483701812271
# epoch: 49  precision: 0.2782986901422694
# [I 2020-07-03 03:59:39,521] Finished trial#0 with value: 0.2782986901422694 with parameters: {'embedding_dim': 80.0, 'batch_size': 256, 'lr': 0.008594062939966108, 'weight_decay': 4.402282005836203e-05, 'warmup': 4, 'lr_decay_every': 4, 'lr_decay_rate': 0.7390427005422271}. Best is trial#0 with value: 0.2782986901422694.
# epoch: 9  precision: 0.05984391273237344
# epoch: 19  precision: 0.11153827934616081
# epoch: 29  precision: 0.12984718505447462
# epoch: 39  precision: 0.13946125462607364
# epoch: 49  precision: 0.1516956847953033
# [I 2020-07-03 04:02:47,771] Finished trial#1 with value: 0.1516956847953033 with parameters: {'embedding_dim': 80.0, 'batch_size': 256, 'lr': 0.0010216161704853577, 'weight_decay': 1.0385359739143982e-05, 'warmup': 1, 'lr_decay_every': 3, 'lr_decay_rate': 0.9756876582278124}. Best is trial#1 with value: 0.1516956847953033.
# epoch: 9  precision: 0.007556532294051722
# epoch: 19  precision: 0.007762254657208488
# epoch: 29  precision: 0.008130367270219058
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7a639114d614> in <module>
#       1 study = optuna.create_study()
# ----> 2 study.optimize(objective, n_trials=3)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     337             if n_jobs == 1:
#     338                 self._optimize_sequential(
# --> 339                     func, n_trials, timeout, catch, callbacks, gc_after_trial, None
#     340                 )
#     341             else:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/optuna/study.py in _optimize_sequential(self, func, n_trials, timeout, catch, callbacks, gc_after_trial, time_start)
#     680                     break
#     681
# --> 682             self._run_trial_and_callbacks(func, catch, callbacks, gc_after_trial)
#     683
#     684             self._progress_bar.update((datetime.datetime.now() - time_start).total_seconds())
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/optuna/study.py in _run_trial_and_callbacks(self, func, catch, callbacks, gc_after_trial)
#     711         # type: (...) -> None
#     712
# --> 713         trial = self._run_trial(func, catch, gc_after_trial)
#     714         if callbacks is not None:
#     715             frozen_trial = copy.deepcopy(self._storage.get_trial(trial._trial_id))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/optuna/study.py in _run_trial(self, func, catch, gc_after_trial)
#     732
#     733         try:
# --> 734             result = func(trial)
#     735         except exceptions.TrialPruned as e:
#     736             message = "Setting status of trial#{} as {}. {}".format(
#
# <ipython-input-3-e42dc7e89b0c> in objective(trial)
#      25
#      26     score =iterater.iterate_epoch(model, lr=lr, epoch=50, weight_decay=weight_decay, warmup=warmup,
# ---> 27                            lr_decay_rate=lr_decay_rate, lr_decay_every=lr_decay_every, eval_every=10)
#      28
#      29     return score
#
# ~/workspace/python_env/workspace/recsys_embed_ppr/KG_Embed/training.py in iterate_epoch(self, model, lr, epoch, weight_decay, warmup, lr_decay_rate, lr_decay_every, eval_every)
#     124
#     125             if (i+1) % eval_every == 0:
# --> 126                 score = eval_model.topn_precision(model)
#     127                 plot_score_list.append(score)
#     128                 print('epoch: {}  precision: {}'.format(i, score))
#
# ~/workspace/python_env/workspace/recsys_embed_ppr/KG_Embed/evaluate.py in topn_precision(self, model, n)
#      30             batch_size = 512
#      31             item_index = [self.dataset.entity_list.index(item) for item in self.dataset.item_list]
# ---> 32             user_index = [self.dataset.entity_list.index(user) for user in self.dataset.user_list]
#      33             for i in user_index:
#      34                 if len(self.dataset.user_items_test_dict[i]) == 0:
#
# ~/workspace/python_env/workspace/recsys_embed_ppr/KG_Embed/evaluate.py in <listcomp>(.0)
#      30             batch_size = 512
#      31             item_index = [self.dataset.entity_list.index(item) for item in self.dataset.item_list]
# ---> 32             user_index = [self.dataset.entity_list.index(user) for user in self.dataset.user_list]
#      33             for i in user_index:
#      34                 if len(self.dataset.user_items_test_dict[i]) == 0:
#
# KeyboardInterrupt:

# %%
df = study.trials_dataframe() # pandasのDataFrame形式
df.head()
